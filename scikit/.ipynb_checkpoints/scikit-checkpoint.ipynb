# %%
# !pip install scikit-image
# Out:
# ...
#   Stored in directory: C:\Users\hogoo\AppData\Local\pip\Cache\wheels\68\f8\29\b53346a112a07d30a5a84d53f19aeadaa1a474897c0423af91
# Successfully built networkx
# ...

# %%
from skimage import data

# %%
dir(data)
# Out:
# ['__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '_binary_blobs',
#  '_detect',
#  '_np',
#  '_os',
#  'astronaut',
#  'binary_blobs',
#  'camera',
#  'checkerboard',
#  'chelsea',
#  'clock',
#  'coffee',
#  'coins',
#  'data_dir',
#  'expected_warnings',
#  'horse',
#  'hubble_deep_field',
#  'img_as_bool',
#  'immunohistochemistry',
#  'imread',
#  'lbp_frontal_face_cascade_filename',
#  'lfw_subset',
#  'load',
#  'logo',
#  'microaneurysms',
#  'moon',
#  'osp',
#  'page',
#  'retina',
#  'rocket',
#  'stereo_motorcycle',
#  'text',
#  'use_plugin',
#  'warn']

# %%
data.camera()
# Out:
# array([[156, 157, 160, ..., 152, 152, 152],
#        [156, 157, 159, ..., 152, 152, 152],
#        [158, 157, 156, ..., 152, 152, 152],
#        ...,
#        [121, 123, 126, ..., 121, 113, 111],
#        [121, 123, 126, ..., 121, 113, 111],
#        [121, 123, 126, ..., 121, 113, 111]], dtype=uint8)

# %%
import matplotlib.pyplot as plt
import matplotlib as mp

# %%
plt.imshow(data.camera())

# %%
plt.imshow(data.camera(),cmap='gray')

# %%
dir(mp.cm)
# Out:
# ['Accent',
#  'Accent_r',
#  'Blues',
#  'Blues_r',
#  'BrBG',
#  'BrBG_r',
#  'BuGn',
#  'BuGn_r',
#  'BuPu',
#  'BuPu_r',
#  'CMRmap',
#  'CMRmap_r',
#  'Dark2',
#  'Dark2_r',
#  'GnBu',
#  'GnBu_r',
#  'Greens',
#  'Greens_r',
#  'Greys',
#  'Greys_r',
#  'LUTSIZE',
#  'OrRd',
#  'OrRd_r',
#  'Oranges',
#  'Oranges_r',
#  'PRGn',
#  'PRGn_r',
#  'Paired',
#  'Paired_r',
#  'Pastel1',
#  'Pastel1_r',
#  'Pastel2',
#  'Pastel2_r',
#  'PiYG',
#  'PiYG_r',
#  'PuBu',
#  'PuBuGn',
#  'PuBuGn_r',
#  'PuBu_r',
#  'PuOr',
#  'PuOr_r',
#  'PuRd',
#  'PuRd_r',
#  'Purples',
#  'Purples_r',
#  'RdBu',
#  'RdBu_r',
#  'RdGy',
#  'RdGy_r',
#  'RdPu',
#  'RdPu_r',
#  'RdYlBu',
#  'RdYlBu_r',
#  'RdYlGn',
#  'RdYlGn_r',
#  'Reds',
#  'Reds_r',
#  'ScalarMappable',
#  'Set1',
#  'Set1_r',
#  'Set2',
#  'Set2_r',
#  'Set3',
#  'Set3_r',
#  'Spectral',
#  'Spectral_r',
#  'Wistia',
#  'Wistia_r',
#  'YlGn',
#  'YlGnBu',
#  'YlGnBu_r',
#  'YlGn_r',
#  'YlOrBr',
#  'YlOrBr_r',
#  'YlOrRd',
# ...

# %%
plt.imshow(data.camera(),cmap='hot_r')

# %% [markdown]
# 이미지를 보여주기 위해서는 좌표정보, 색깔정보가 있어야 한다.
# 그런데 위의 camera는 예제 데이터를 포함하고 있는 사진이며, 색깔 정보를 따로 주지 않았다.
# 이런 경우는 default로 설정되어있는 설정을 적용해서 녹색 계열의 사진이 로드된다.
# 따라서 색상정보를 넣어줄 때 마다 컬러값이 바뀐다.

# %%
dir(data)
# Out:
# ['__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '_binary_blobs',
#  '_detect',
#  '_np',
#  '_os',
#  'astronaut',
#  'binary_blobs',
#  'camera',
#  'checkerboard',
#  'chelsea',
#  'clock',
#  'coffee',
#  'coins',
#  'data_dir',
#  'expected_warnings',
#  'horse',
#  'hubble_deep_field',
#  'img_as_bool',
#  'immunohistochemistry',
#  'imread',
#  'lbp_frontal_face_cascade_filename',
#  'lfw_subset',
#  'load',
#  'logo',
#  'microaneurysms',
#  'moon',
#  'osp',
#  'page',
#  'retina',
#  'rocket',
#  'stereo_motorcycle',
#  'text',
#  'use_plugin',
#  'warn']

# %%
k = data.imread('../images/샤키리.png') #scikit은 따로 변환할 필요 없이 numpy로 불러들인다.

# %%
k
# Out:
# array([[[228, 231, 224, 255],
#         [226, 229, 221, 255],
#         [227, 230, 221, 255],
#         ...,
#         [ 33,  43,  35, 255],
#         [ 33,  42,  35, 255],
#         [ 34,  42,  35, 255]],
#
#        [[224, 227, 220, 255],
#         [224, 227, 219, 255],
#         [225, 228, 219, 255],
#         ...,
#         [ 34,  43,  36, 255],
#         [ 35,  43,  36, 255],
#         [ 36,  43,  36, 255]],
#
#        [[227, 230, 223, 255],
#         [227, 230, 222, 255],
#         [228, 231, 222, 255],
#         ...,
#         [ 37,  44,  37, 255],
#         [ 38,  43,  37, 255],
#         [ 41,  43,  39, 255]],
#
#        ...,
#
#        [[ 18,  26,  24, 255],
#         [ 19,  28,  24, 255],
#         [ 20,  28,  23, 255],
#         ...,
#         [ 90,  94,  75, 255],
#         [ 89,  93,  74, 255],
#         [ 90,  94,  74, 255]],
#
#        [[ 17,  25,  24, 255],
#         [ 18,  27,  23, 255],
#         [ 20,  28,  21, 255],
#         ...,
#         [ 90,  93,  77, 255],
# ...

# %%
k.shape
# Out:
# (342, 650, 4)

# %%
k.dtype
# Out:
# dtype('uint8')

# %% [markdown]
# http://scikit-image.org/docs/stable/user_guide.html

# %%
plt.imshow(data.chelsea())

# %%
plt.imshow(data.chelsea()[::-1,:,:])

# %%
a = [1,2,3,4,5,]

# %%
b = a[::-1]

# %%
b
# Out:
# [5, 4, 3, 2, 1]
