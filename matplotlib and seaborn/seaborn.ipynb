# %%
#http://seaborn.pydata.org/tutorial/axis_grids.html

# %%
import seaborn as sns

# %%
iris = sns.load_dataset('iris')

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# 5             5.4          3.9           1.7          0.4     setosa
# 6             4.6          3.4           1.4          0.3     setosa
# 7             5.0          3.4           1.5          0.2     setosa
# 8             4.4          2.9           1.4          0.2     setosa
# 9             4.9          3.1           1.5          0.1     setosa
# 10            5.4          3.7           1.5          0.2     setosa
# 11            4.8          3.4           1.6          0.2     setosa
# 12            4.8          3.0           1.4          0.1     setosa
# ...

# %%
sns.pairplot(iris)

# %%
iris.corr()
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %%
sns.pairplot(iris, hue='species')

# %%
sns.pairplot(iris, hue='species', kind = 'reg')

# %%
sns.FacetGrid(iris, 'sepal_width', 'sepal_length')

# %%
tips = sns.load_dataset('tips')

# %%
sns.FacetGrid(tips, col='sex')

# %%
import matplotlib.pyplot as plt

# %%
g = sns.FacetGrid(tips, col='sex', hue='smoker')
g.map(plt.scatter,'tip','total_bill')
g.add_legend()

# %%
fig,ax = plt.subplots(tips.day.nunique())

# %%
iris = sns.load_dataset('iris')
g = sns.PairGrid(iris)
g.map(plt.scatter)

# %%
g = sns.PairGrid(iris, hue='species')
g.map_diag(plt.hist)
g.map_offdiag(plt.scatter)
g.add_legend()
#이 모든 과정을 한번에 해 주는게 Pairplot

# %%
k=tips.groupby('smoker')
k.plot.bar()
# Out:
# smoker
# Yes    AxesSubplot(0.125,0.125;0.775x0.755)
# No     AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object

# %%
k.plot.box()
# Out:
# smoker
# Yes    AxesSubplot(0.125,0.125;0.775x0.755)
# No     AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object

# %%
k.plot(kind='box')
# Out:
# smoker
# Yes    AxesSubplot(0.125,0.125;0.775x0.755)
# No     AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object

# %%
k.plot.box()
# Out:
# smoker
# Yes    AxesSubplot(0.125,0.125;0.775x0.755)
# No     AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object

# %%
k.boxplot()
# Out:
# Yes         AxesSubplot(0.1,0.15;0.363636x0.75)
# No     AxesSubplot(0.536364,0.15;0.363636x0.75)
# dtype: object
