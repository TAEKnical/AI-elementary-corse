# %%
 import pandas as pd

# %%
raw_data = {
    'subject_id' : ['1','2','3','4','5','7','8','9','10','11'],
    'test_score' : [51, 15, 15, 61, 16, 14, 15, 1, 61, 16]
}
df_a = pd.DataFrame(raw_data, columns = ['subject_id','test_score'])

# %%
df_a
# Out:
#   subject_id  test_score
# 0          1          51
# 1          2          15
# 2          3          15
# 3          4          61
# 4          5          16
# 5          7          14
# 6          8          15
# 7          9           1
# 8         10          61
# 9         11          16

# %%
raw_data = {
        'subject_id' : ['4','5','6','7','8'],
        'first_name' : ['Billy','Brian','Bran','Bryce','Betty'],
        'last_name' : ['Bonder','Black','Balwner','Brice','Btisan']
}
df_b = pd.DataFrame(raw_data, columns = ['subject_id','first_name','last_name'])
df_b
# Out:
#   subject_id first_name last_name
# 0          4      Billy    Bonder
# 1          5      Brian     Black
# 2          6       Bran   Balwner
# 3          7      Bryce     Brice
# 4          8      Betty    Btisan

# %%
pd.merge(df_a,df_b,on='subject_id') #합치는 기준이 되는 컬럼 지정
# Out:
#   subject_id  test_score first_name last_name
# 0          4          61      Billy    Bonder
# 1          5          16      Brian     Black
# 2          7          14      Bryce     Brice
# 3          8          15      Betty    Btisan

# %%
pd.merge(df_a,df_b,left_on='subject_id', right_on='subject_id')
#a의 subject_id와 b의 subject_id에서 겹치는 것만 가져오기
# Out:
#   subject_id  test_score first_name last_name
# 0          4          61      Billy    Bonder
# 1          5          16      Brian     Black
# 2          7          14      Bryce     Brice
# 3          8          15      Betty    Btisan

# %% [markdown]
# #### left,right개념은 벤다이어그램을 떠올리면 쉽다.

# %%
pd.merge(df_a,df_b,on='subject_id',how='left')
#a의 subject_id를 기준으로 하며 a + a와b의 교집합만 표시
#left의 의미는 왼쪽을 기준으로 추가한다는 뜻.
# Out:
#   subject_id  test_score first_name last_name
# 0          1          51        NaN       NaN
# 1          2          15        NaN       NaN
# 2          3          15        NaN       NaN
# 3          4          61      Billy    Bonder
# 4          5          16      Brian     Black
# 5          7          14      Bryce     Brice
# 6          8          15      Betty    Btisan
# 7          9           1        NaN       NaN
# 8         10          61        NaN       NaN
# 9         11          16        NaN       NaN

# %%
pd.merge(df_a,df_b,on='subject_id', how='right')
#b의 subject_id를 기준으로하며 b + a와b의 교집합을 표시
#right는 오른쪽을 먼저 추가하고 그를 기준으로 왼쪽으로 늘려간다는 뜻.
# Out:
#   subject_id  test_score first_name last_name
# 0          4        61.0      Billy    Bonder
# 1          5        16.0      Brian     Black
# 2          7        14.0      Bryce     Brice
# 3          8        15.0      Betty    Btisan
# 4          6         NaN       Bran   Balwner

# %%
pd.merge(df_a,df_b,on='subject_id',how='outer')
#outer는 양쪽이 다 나오면서 있을 경우는 합쳐주고 없으면 합쳐주지 않는다.
# Out:
#    subject_id  test_score first_name last_name
# 0           1        51.0        NaN       NaN
# 1           2        15.0        NaN       NaN
# 2           3        15.0        NaN       NaN
# 3           4        61.0      Billy    Bonder
# 4           5        16.0      Brian     Black
# 5           7        14.0      Bryce     Brice
# 6           8        15.0      Betty    Btisan
# 7           9         1.0        NaN       NaN
# 8          10        61.0        NaN       NaN
# 9          11        16.0        NaN       NaN
# 10          6         NaN       Bran   Balwner

# %%
pd.merge(df_a,df_b,on='subject_id',how='inner')
#a와b의 subjectid를 기준으로하며 a교집합b만 출력
# Out:
#   subject_id  test_score first_name last_name
# 0          4          61      Billy    Bonder
# 1          5          16      Brian     Black
# 2          7          14      Bryce     Brice
# 3          8          15      Betty    Btisan

# %%
pd.merge(df_a,df_b,right_index=True,left_index=True)
# Out:
#   subject_id_x  test_score subject_id_y first_name last_name
# 0            1          51            4      Billy    Bonder
# 1            2          15            5      Brian     Black
# 2            3          15            6       Bran   Balwner
# 3            4          61            7      Bryce     Brice
# 4            5          16            8      Betty    Btisan

# %% [markdown]
# ## concat

# %%
raw_data = {
    'subject_id' : ['1','2','3','4','5'],
    'first_name' : ['Alex','Amy','Allen','Alice','Ayoung'],
    'last_name' : ['Anderson','Ackerman','Ali','Aoni','Atiches']
}
df_a  = pd.DataFrame(raw_data, columns=['subject_id','first_name','last_name'])
df_a
# Out:
#   subject_id first_name last_name
# 0          1       Alex  Anderson
# 1          2        Amy  Ackerman
# 2          3      Allen       Ali
# 3          4      Alice      Aoni
# 4          5     Ayoung   Atiches

# %%
raw_data = {
    'subject_id' : ['4','5','6','7','8'],
    'first_name' : ['Billy','Brian','Bran','Bryce','Betty'],
    'last_name' : ['Bonder','Black','Balwner','Brice','Btisan']
}
df_a = pd.DataFrame(raw_data, columns=['subject_id','first_name','last_name'])

# %%
df_new = pd.concat([df_a,df_b])
df_new
# Out:
#   subject_id first_name last_name
# 0          4      Billy    Bonder
# 1          5      Brian     Black
# 2          6       Bran   Balwner
# 3          7      Bryce     Brice
# 4          8      Betty    Btisan
# 0          4      Billy    Bonder
# 1          5      Brian     Black
# 2          6       Bran   Balwner
# 3          7      Bryce     Brice
# 4          8      Betty    Btisan

# %%
df_new = pd.concat([df_a,df_b])
df_new.reset_index()
# Out:
#    index subject_id first_name last_name
# 0      0          4      Billy    Bonder
# 1      1          5      Brian     Black
# 2      2          6       Bran   Balwner
# 3      3          7      Bryce     Brice
# 4      4          8      Betty    Btisan
# 5      0          4      Billy    Bonder
# 6      1          5      Brian     Black
# 7      2          6       Bran   Balwner
# 8      3          7      Bryce     Brice
# 9      4          8      Betty    Btisan

# %%
df_a.append(df_b)
# Out:
#   subject_id first_name last_name
# 0          4      Billy    Bonder
# 1          5      Brian     Black
# 2          6       Bran   Balwner
# 3          7      Bryce     Brice
# 4          8      Betty    Btisan
# 0          4      Billy    Bonder
# 1          5      Brian     Black
# 2          6       Bran   Balwner
# 3          7      Bryce     Brice
# 4          8      Betty    Btisan

# %% [markdown]
#  concat은 기본적으로 세로로 붙인다. 가로로 붙이려면?

# %%
df_new = pd.concat([df_a,df_b],axis=1)
df_new
# Out:
#   subject_id first_name last_name subject_id first_name last_name
# 0          4      Billy    Bonder          4      Billy    Bonder
# 1          5      Brian     Black          5      Brian     Black
# 2          6       Bran   Balwner          6       Bran   Balwner
# 3          7      Bryce     Brice          7      Bryce     Brice
# 4          8      Betty    Btisan          8      Betty    Btisan

# %% [markdown]
# ## Case study

# %%
import os

# %%
files = [file_name for file_name in os.listdir('./data') if file_name.endswith('xlsx')]
files.remove('excel-comp-data.xlsx')
files
# Out:
# ['customer-status.xlsx',
#  'sales-feb-2014.xlsx',
#  'sales-jan-2014.xlsx',
#  'sales-mar-2014.xlsx']

# %%
df_list[0]
# Out:
#     account number                             name  status
# 0           740150                       Barton LLC    gold
# 1           714466                  Trantow-Barrows  silver
# 2           218895                        Kulas Inc  bronze
# 3           307599      Kassulke, Ondricka and Metz  bronze
# 4           412290                    Jerde-Hilpert  bronze
# 5           729833                        Koepp Ltd  silver
# 6           146832                     Kiehn-Spinka  silver
# 7           688981                      Keeling LLC  silver
# 8           786968         Frami, Hills and Schmidt  silver
# 9           239344                       Stokes LLC    gold
# 10          672390                  Kuhn-Gusikowski  silver
# 11          141962                       Herman LLC    gold
# 12          424914                    White-Trantow  silver
# 13          527099                 Sanford and Sons  bronze
# 14          642753                      Pollich LLC  bronze
# ...

# %%
df_list[1]
# Out:
#      account number                             name       sku  quantity  \
# 0            383080                         Will LLC  B1-20000         7
# 1            412290                    Jerde-Hilpert  S1-27722        11
# 2            412290                    Jerde-Hilpert  B1-86481         3
# 3            412290                    Jerde-Hilpert  B1-20000        23
# 4            672390                  Kuhn-Gusikowski  S1-06532        48
# 5            383080                         Will LLC  S1-82801        21
# 6            714466                  Trantow-Barrows  S1-06532         9
# 7            239344                       Stokes LLC  S1-47412        44
# 8            672390                  Kuhn-Gusikowski  S1-27722        36
# 9            307599      Kassulke, Ondricka and Metz  S1-27722        32
# 10           642753                      Pollich LLC  B1-33087        23
# 11           642753                      Pollich LLC  B1-33364         3
# ...

# %%
df_list[2]
# Out:
#      account number                             name       sku  quantity  \
# 0            740150                       Barton LLC  B1-20000        39
# 1            714466                  Trantow-Barrows  S2-77896        -1
# 2            218895                        Kulas Inc  B1-69924        23
# 3            307599      Kassulke, Ondricka and Metz  S1-65481        41
# 4            412290                    Jerde-Hilpert  S2-34077         6
# 5            714466                  Trantow-Barrows  S2-77896        17
# 6            218895                        Kulas Inc  B1-65551         2
# 7            729833                        Koepp Ltd  S1-30248         8
# 8            714466                  Trantow-Barrows  S1-50961        22
# 9            737550     Fritsch, Russel and Anderson  S2-82423        14
# 10           146832                     Kiehn-Spinka  S2-82423        15
# 11           688981                      Keeling LLC  S2-00301         7
# ...

# %%
df_list[3]
# Out:
#      account number                             name       sku  quantity  \
# 0            163416                      Purdy-Kunde  S1-30248        19
# 1            527099                 Sanford and Sons  S2-82423         3
# 2            527099                 Sanford and Sons  B1-50809         8
# 3            737550     Fritsch, Russel and Anderson  B1-50809        20
# 4            688981                      Keeling LLC  B1-86481        -1
# 5            729833                        Koepp Ltd  S1-82801        26
# 6            307599      Kassulke, Ondricka and Metz  S1-93683        -1
# 7            412290                    Jerde-Hilpert  S2-23246        27
# 8            307599      Kassulke, Ondricka and Metz  S2-34077        48
# 9            141962                       Herman LLC  S2-10342        49
# 10           257198  Cronin, Oberbrunner and Spencer  S2-16558         7
# 11           257198  Cronin, Oberbrunner and Spencer  S2-23246        40
# ...

# %%
df_list = [pd.read_excel('./data/'+df_filename) for df_filename in files]
status = df_list[0]
sales = pd.concat(df_list[1:])

# %%
status.head()
# Out:
#    account number                         name  status
# 0          740150                   Barton LLC    gold
# 1          714466              Trantow-Barrows  silver
# 2          218895                    Kulas Inc  bronze
# 3          307599  Kassulke, Ondricka and Metz  bronze
# 4          412290                Jerde-Hilpert  bronze

# %%
sales.head()
# Out:
#    account number             name       sku  quantity  unit price  ext price  \
# 0          383080         Will LLC  B1-20000         7       33.69     235.83
# 1          412290    Jerde-Hilpert  S1-27722        11       21.12     232.32
# 2          412290    Jerde-Hilpert  B1-86481         3       35.99     107.97
# 3          412290    Jerde-Hilpert  B1-20000        23       78.90    1814.70
# 4          672390  Kuhn-Gusikowski  S1-06532        48       55.82    2679.36
#
#                   date
# 0  2014-02-01 09:04:59
# 1  2014-02-01 11:51:46
# 2  2014-02-01 17:24:32
# 3  2014-02-01 19:56:48
# 4  2014-02-02 03:45:20

# %%
merge_df = pd.merge(status, sales, how='inner',on='account number')
merge_df.head()
# Out:
#    account number      name_x status      name_y       sku  quantity  \
# 0          740150  Barton LLC   gold  Barton LLC  S1-93683        21
# 1          740150  Barton LLC   gold  Barton LLC  S2-10342        47
# 2          740150  Barton LLC   gold  Barton LLC  B1-38851         3
# 3          740150  Barton LLC   gold  Barton LLC  B1-20000        28
# 4          740150  Barton LLC   gold  Barton LLC  B1-38851        17
#
#    unit price  ext price                 date
# 0       10.34     217.14  2014-02-07 08:34:50
# 1       96.68    4543.96  2014-02-12 03:36:52
# 2       79.49     238.47  2014-02-12 05:09:16
# 3       81.39    2278.92  2014-02-15 07:45:16
# 4       81.22    1380.74  2014-02-17 17:12:16

# %%
merge_df.groupby(['status','name_x'])['quantity','ext price'].sum()
# Out:
#                                         quantity  ext price
# status name_x
# bronze Jerde-Hilpert                         581   30617.51
#        Kassulke, Ondricka and Metz           366   20543.71
#        Kulas Inc                             738   53507.36
#        Pollich LLC                           219    9298.02
#        Sanford and Sons                      403   24003.93
# gold   Barton LLC                            346   21909.13
#        Cronin, Oberbrunner and Spencer       543   26809.63
#        Herman LLC                            417   22940.82
#        Stokes LLC                            449   25680.43
# silver Frami, Hills and Schmidt              338   19634.31
#        Keeling LLC                           438   27341.41
#        Kiehn-Spinka                          350   21027.06
#        Koepp Ltd                             315   17381.89
#        Kuhn-Gusikowski                       558   29994.43
# ...

# %%
merge_df.groupby(['status','name_x'])['quantity','ext price'].sum().reset_index()
# Out:
#     status                           name_x  quantity  ext price
# 0   bronze                    Jerde-Hilpert       581   30617.51
# 1   bronze      Kassulke, Ondricka and Metz       366   20543.71
# 2   bronze                        Kulas Inc       738   53507.36
# 3   bronze                      Pollich LLC       219    9298.02
# 4   bronze                 Sanford and Sons       403   24003.93
# 5     gold                       Barton LLC       346   21909.13
# 6     gold  Cronin, Oberbrunner and Spencer       543   26809.63
# 7     gold                       Herman LLC       417   22940.82
# 8     gold                       Stokes LLC       449   25680.43
# 9   silver         Frami, Hills and Schmidt       338   19634.31
# 10  silver                      Keeling LLC       438   27341.41
# 11  silver                     Kiehn-Spinka       350   21027.06
# 12  silver                        Koepp Ltd       315   17381.89
# ...

# %%
merge_df.groupby(['status','name_x'])['quantity','ext price'].sum().reset_index().sort_values(
by=['status','quantity'],ascending=False)
# Out:
#     status                           name_x  quantity  ext price
# 14  silver                  Trantow-Barrows       643   35354.61
# 13  silver                  Kuhn-Gusikowski       558   29994.43
# 15  silver                    White-Trantow       556   34070.80
# 10  silver                      Keeling LLC       438   27341.41
# 11  silver                     Kiehn-Spinka       350   21027.06
# 9   silver         Frami, Hills and Schmidt       338   19634.31
# 12  silver                        Koepp Ltd       315   17381.89
# 6     gold  Cronin, Oberbrunner and Spencer       543   26809.63
# 8     gold                       Stokes LLC       449   25680.43
# 7     gold                       Herman LLC       417   22940.82
# 5     gold                       Barton LLC       346   21909.13
# 2   bronze                        Kulas Inc       738   53507.36
# 0   bronze                    Jerde-Hilpert       581   30617.51
# ...
